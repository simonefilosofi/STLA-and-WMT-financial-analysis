# %%
import pandas as pd

# Reading the CSV files into DataFrames
stlaMetrics = pd.read_csv('Outputs\stla_metrics.csv')
wmtMetrics = pd.read_csv('Outputs\wmt_metrics.csv')
walmart_balance_sheet = pd.read_csv('Dataset\wmt_balance_sheet.csv')
stellantis_balance_sheet = pd.read_csv('Dataset\stla_balance_sheet.csv')
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:6: SyntaxWarning: invalid escape sequence '\w'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:6: SyntaxWarning: invalid escape sequence '\w'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Utente\AppData\Local\Temp\ipykernel_36524\459724436.py:4: SyntaxWarning: invalid escape sequence '\s'
#   stlaMetrics = pd.read_csv('Outputs\stla_metrics.csv')
# C:\Users\Utente\AppData\Local\Temp\ipykernel_36524\459724436.py:5: SyntaxWarning: invalid escape sequence '\w'
#   wmtMetrics = pd.read_csv('Outputs\wmt_metrics.csv')
# C:\Users\Utente\AppData\Local\Temp\ipykernel_36524\459724436.py:6: SyntaxWarning: invalid escape sequence '\w'
#   walmart_balance_sheet = pd.read_csv('Dataset\wmt_balance_sheet.csv')
# ...

# %%
# Part 1: Capital Structure Analysis

# Manual input of data for Walmart (WMT) and Stellantis (STLA)
# These values are based on recent financial information

# Walmart data
wmtShares = wmtMetrics['2025-01-31'][0]  # Number of shares
print("Walmart Shares:", wmtShares)
wmtPrice = 98.16  # Price per share in USD 
wmtTotEquity = wmtMetrics['2025-01-31'][6] # Stockholders' Equity from wmt_balance_sheet.csv
print("Walmart Total Equity:", wmtTotEquity)
wmtMarketCap = (wmtShares * wmtPrice)  # Market capitalization 
print("Walmart Market Capitalization:", wmtMarketCap)
wmtTotDebt = wmtMetrics['2025-01-31'][8] # Total debt from wmt_balance_sheet.csv
print("Walmart Total Debt:", wmtTotDebt)
wmtTotAssets = wmtMetrics['2025-01-31'][1]  # Total Assets from wmt_balance_sheet.csv
print("Walmart Total Assets:", wmtTotAssets)
wmtTotCapital = wmtTotEquity + wmtTotDebt
print("Walmart Total Capital:", wmtTotCapital)
wmtTotLiabilities = wmtMetrics['2025-01-31'][5]  # Total Liabilities from wmt_balance_sheet.csv


# Stellantis data
stlaTotLiabilities = stlaMetrics['2024-12-31'][6]  # Total Liabilities from wmt_balance_sheet.csv
print("Stellantis Total Liabilities:", stlaTotLiabilities)
stlaShares = stlaMetrics['2024-12-31'][4]  # Number of shares
print("Stellantis Shares:", stlaShares)
stlaPrice = 13.05  # Price per share in USD 
stlaTotEquity = stlaMetrics['2024-12-31'][9] # Stockholders' Equity from wmt_balance_sheet.csv
print("Stellantis Total Equity:", stlaTotEquity)
stlaMarketCap = (stlaShares * stlaPrice)  # Market capitalization 
print("Stellantis Market Capitalization:", stlaMarketCap)
stlaTotDebt = stlaMetrics['2024-12-31'][8] # Total debt from wmt_balance_sheet.csv
print("Stellantis Total Debt:", stlaTotDebt)
stlaTotAssets = stlaMetrics['2024-12-31'][0]  # Total Assets from wmt_balance_sheet.csv
print("Stellantis Total Assets:", stlaTotAssets)
stlaTotCapital = stlaTotEquity + stlaTotDebt
print("Stellantis Total Capital:", stlaTotCapital)


# Calculate capital structure metrics
print("========== CAPITAL STRUCTURE ANALYSIS ==========")

# Walmart Capital Structure
# wmt_debt_ratio = wmt_total_debt / wmt_total_assets, changed to wmt_debt_ratio = wmt_total_debt / wmt_total_capital because of the WACC Calculation  below not matching online calculations
wmtDebtRatio = wmtTotDebt / wmtTotCapital
# wmt_equity_ratio = wmt_total_equity / wmt_total_assets changed to wmt_Equity_ratio = wmt_total_equity / wmt_total_capital because of the WACC Calculation  below not matching online calculations
wmtEqRatio = wmtTotEquity / wmtTotCapital
wmtDebEqRatio = wmtTotDebt / wmtTotEquity

print("\nWalmart (WMT) Capital Structure:")
print("Market Capitalization: (Shares * Price) $", wmtMarketCap)
print("Total Debt: $", wmtTotDebt)
print("Total Assets: $", wmtTotAssets)
print("Debt Ratio (D/A):", round(wmtDebtRatio * 100, 2), "%")
print("Equity Ratio (E/A):", round(wmtEqRatio * 100, 2), "%")
print("Debt-Equity Ratio (D/E):", round(wmtDebEqRatio * 100, 2), "%")

# Stellantis Capital Structure
# stla_debt_ratio = stla_total_debt / stla_total_assets changed to stla_debt_ratio = stla_total_debt / stla_total_capital because of the WACC Calculation  below not matching online calculations
stlaDebtRatio = stlaTotDebt / stlaTotCapital
# stla_equity_ratio = stla_total_equity / stla_total_assets changed to stla_equity_ratio = stla_total_equity / stla_total_capital because of the WACC Calculation  below not matching online calculations
stlaEqRatio = stlaTotEquity / stlaTotCapital
stlaDebEqRatio = stlaTotDebt / stlaTotEquity

print("\nStellantis (STLA) Capital Structure:")
print("Market Capitalization:(Shares * Price) $", stlaMarketCap)
print("Total Debt: $", stlaTotDebt)
print("Total Assets: $", stlaTotAssets)
print("Debt Ratio (D/A):", round(stlaDebtRatio * 100, 2), "%")
print("Equity Ratio (E/A):", round(stlaEqRatio * 100, 2), "%")
print("Debt-Equity Ratio (D/E):", round(stlaDebEqRatio * 100, 2), "%")


# Capital structure comparison
print("\nCapital Structure Comparison:")
print("Walmart Debt Ratio:", round(wmtDebtRatio * 100, 2), "% vs. Stellantis Debt Ratio:", round(stlaDebtRatio * 100, 2), "%")\
# Out:
# Walmart Shares: 8024000000.0
# Walmart Total Equity: 97692000000.0
# Walmart Market Capitalization: 787635840000.0
# Walmart Total Debt: 60114000000.0
# Walmart Total Assets: 260823000000.0
# Walmart Total Capital: 157806000000.0
# Stellantis Total Liabilities: 125492000000.0
# Stellantis Shares: 2896073567.0
# Stellantis Total Equity: 82115000000.0
# Stellantis Market Capitalization: 37793760049.35
# Stellantis Total Debt: 37227000000.0
# Stellantis Total Assets: 207607000000.0
# Stellantis Total Capital: 119342000000.0
# ========== CAPITAL STRUCTURE ANALYSIS ==========
#
# Walmart (WMT) Capital Structure:
# Market Capitalization: (Shares * Price) $ 787635840000.0
# Total Debt: $ 60114000000.0
# Total Assets: $ 260823000000.0
# Debt Ratio (D/A): 38.09 %
# Equity Ratio (E/A): 61.91 %
# Debt-Equity Ratio (D/E): 61.53 %
#
# Stellantis (STLA) Capital Structure:
# Market Capitalization:(Shares * Price) $ 37793760049.35
# Total Debt: $ 37227000000.0
# Total Assets: $ 207607000000.0
# ...

# %%
# Add visualization for capital structure comparison
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

# Use a visually appealing style
plt.style.use('seaborn-v0_8-whitegrid')

# Create data for stacked bar chart
companies = ['Walmart', 'Stellantis']
debt = np.array([wmtDebtRatio * 100, stlaDebtRatio * 100])
equity = np.array([wmtEqRatio * 100, stlaEqRatio * 100])

# Create the stacked bar chart
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.6 # Slightly wider bars

# Define more distinct colors
color_debt = '#d62728' # Reddish
color_equity = '#1f77b4' # Bluish

# Plot bars with edge color and slight transparency
ax.bar(companies, debt, width=bar_width, label='Debt %', color=color_debt, alpha=0.85, edgecolor='black', linewidth=0.5)
ax.bar(companies, equity, width=bar_width, bottom=debt, label='Equity %', color=color_equity, alpha=0.85, edgecolor='black', linewidth=0.5)

# Add labels and title with enhanced formatting
ax.set_ylabel('Percentage of Total Assets (%)', fontsize=11)
ax.set_title('Capital Structure: Debt vs. Equity Ratio', fontsize=14, fontweight='bold', pad=20)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.08), ncol=2, frameon=False) # Move legend below

# Format y-axis as percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylim(0, 100) # Ensure y-axis goes up to 100%

# Add percentage labels on the bars with improved appearance
for i, company in enumerate(companies):
    # Debt label
    if debt[i] > 5: # Only add label if section is large enough
        ax.text(i, debt[i] / 2, f"{debt[i]:.1f}%",
                ha='center', va='center', fontweight='bold', color='white', fontsize=10)
    # Equity label
    if equity[i] > 5: # Only add label if section is large enough
        ax.text(i, debt[i] + (equity[i] / 2), f"{equity[i]:.1f}%",
                ha='center', va='center', fontweight='bold', color='white', fontsize=10)

# Remove top and right spines for a cleaner look
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('grey')
ax.spines['bottom'].set_color('grey')

# Add subtle grid lines
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=0.5)
ax.xaxis.grid(False) # Keep x-axis grid off

# Adjust layout
plt.tight_layout(rect=[0, 0.05, 1, 0.95]) # Adjust rect to make space for legend
plt.show()

# %% [markdown]
# # Capital Structure Analysis: Walmart vs. Stellantis
#
# ## 1. Overview of Capital Structure
#
# Capital structure represents how a company finances its overall operations and growth using different sources of funds, primarily through a combination of equity and debt. The analysis of a company's capital structure provides critical insights into its financial risk profile, financial flexibility, and overall financial health.
#
# For this analysis, we compare the capital structures of two major corporations operating in different sectors:
# - **Walmart (WMT)**: The world's largest retailer
# - **Stellantis (STLA)**: A global automotive manufacturer formed by the merger of Fiat Chrysler Automobiles and the PSA Group
#
# ## 2. Key Metrics Analysis
#
# Based on the financial data provided, here's a comparative analysis of the capital structures:
#
# | Metric | Walmart (WMT) | Stellantis (STLA) |
# |--------|---------------|-------------------|
# | Market Capitalization | $787.64 billion | $37.79 billion |
# | Total Debt | $60.11 billion | $37.23 billion |
# | Total Assets | $260.82 billion | $207.61 billion |
# | Debt Ratio (D/A) | 23.05% | 17.93% |
# | Equity Ratio (E/A) | 34.89% | 39.35% |
# | Debt-Equity Ratio (D/E) | 66.05% | 45.57% |
#
# ## 3. Interpretation of Results
#
# ### 3.1 Walmart's Capital Structure
#
# Walmart demonstrates a moderate capital structure with 23.05% of its total assets financed by debt. This approach offers several strategic advantages:
#
# - **Financial Stability**: With a debt ratio of 23.05%, Walmart maintains good financial stability while still leveraging debt to enhance returns.
# - **Moderate Financial Risk**: The debt-to-equity ratio of 66.05% indicates that Walmart has taken on a moderate level of financial risk, balancing leverage with shareholder investment.
# - **Solid Equity Base**: The 34.89% equity ratio provides a reasonable cushion against business adversities and economic downturns.
# - **Balanced Interest Burden**: The moderate debt level means Walmart has manageable interest expenses while still benefiting from the tax shield that debt provides.
#
# Walmart's approach aligns with the retail industry's need to balance financial leverage with stability due to the sector's thin margins and susceptibility to economic cycles.
#
# ### 3.2 Stellantis's Capital Structure
#
# Stellantis employs a capital structure with debt constituting 17.93% of total assets, which is actually lower than Walmart's debt ratio. This approach offers different strategic considerations:
#
# - **Lower Financial Leverage**: The debt-to-assets ratio of 17.93% indicates Stellantis is using less debt financing relative to its asset base than Walmart.
# - **Lower Debt-to-Equity**: The debt-equity ratio of 45.57% is significantly lower than Walmart's 66.05%, suggesting a more conservative approach to financial leverage.
# - **Stronger Equity Position**: With an equity ratio of 39.35%, Stellantis maintains a stronger proportional equity base compared to Walmart's 34.89%.
# - **Industry Consideration**: Despite the automotive industry typically carrying higher debt levels due to capital-intensive operations, Stellantis appears to maintain a relatively conservative balance sheet.
#
# ### 3.3 Comparative Analysis
#
# The difference in capital structures (23.05% debt ratio for Walmart vs. 17.93% for Stellantis) reflects:
#
# 1. **Industry Strategy Variations**: Despite expectations that automotive manufacturing would be more debt-intensive than retail, Stellantis shows a more conservative approach to debt than Walmart.
#
# 2. **Business Risk Management**: Walmart appears to offset its operational risks with somewhat higher financial leverage, while Stellantis maintains lower financial leverage despite its capital-intensive industry.
#
# 3. **Regional Differences**: The capital structure difference may reflect different financial practices between predominantly US-based Walmart and European-rooted Stellantis.
#
# 4. **Recent Restructuring**: Stellantis's lower debt ratio might reflect recent post-merger financial restructuring and debt management strategies.
#
# ## 4. Implications for Financial Performance
#
# ### 4.1 Cost of Capital Considerations
#
# - **Walmart**: With its higher debt ratio, Walmart may benefit from the tax shield effect of debt, potentially lowering its weighted average cost of capital (WACC). However, the higher debt-to-equity ratio might increase the required return on equity.
#
# - **Stellantis**: The lower debt proportion might result in a higher WACC as the company relies more on equity financing, which typically demands higher returns than debt. However, this could be offset by lower financial risk premiums on both debt and equity.
#
# ### 4.2 Financial Flexibility and Risk
#
# - **Walmart's** higher debt ratio of 23.05% suggests less immediate financial flexibility compared to Stellantis, though it still maintains a reasonable capacity for additional borrowing if needed.
#
# - **Stellantis** has greater financial flexibility with its lower debt ratio of 17.93%, which could be advantageous for major investments in electric vehicle technology and other future growth initiatives.
#
# ## 5. Strategic Considerations
#
# ### 5.1 For Walmart
#
# - Walmart's higher leverage suggests a strategy that balances growth funding with shareholder returns.
# - The 66.05% debt-to-equity ratio indicates Walmart is willing to take on moderate financial risk to enhance returns to shareholders.
# - Walmart should monitor its higher relative debt levels to ensure they remain manageable in different economic environments.
#
# ### 5.2 For Stellantis
#
# - Stellantis could potentially increase shareholder returns by moderately increasing its debt levels, especially to fund the transition to electric vehicles.
# - The lower debt-to-equity ratio of 45.57% provides Stellantis with significant untapped debt capacity.
# - This financial conservatism may provide strategic advantages in an industry undergoing significant technological transformation.
#
# ## 6. Conclusion
#
# The capital structure comparison between Walmart and Stellantis highlights interesting contrasts between these industry leaders. Contrary to typical industry patterns, Walmart shows a higher debt ratio than Stellantis, challenging conventional expectations that automotive manufacturers would be more heavily leveraged than retailers.
#
# Walmart's slightly higher leverage reflects a balanced approach to capital allocation, while Stellantis's more conservative debt profile provides enhanced financial flexibility during a period of significant industry transformation.
#
# Neither approach is inherently superior—each represents a strategic choice aligned with company-specific goals, business risks, and corporate strategy. The optimal capital structure for any company depends on balancing the tax advantages of debt against increased financial risk, while considering industry dynamics, growth opportunities, and macroeconomic conditions.
#
# For investors, understanding these capital structure differences is essential when evaluating the risk and return profiles of companies across different sectors. For financial managers, regularly reassessing the optimal capital structure remains a critical component of strategic financial management.

# %%
# Part 2: Cost of Capital Analysis

# Additional data needed for WACC calculation
betaResults = pd.read_csv('Outputs\\beta_results.csv')
wmt_beta = betaResults['Beta'][0]
print(f"Beta for Walmart is: {wmt_beta}")
stla_beta = betaResults['Beta'][1]
print(f"Beta for Stellantis is: {stla_beta}")

# CAPM and WACC parameters
risk_free_rate = 0.0427 #do not divide by 12
market_risk_premium = 0.055  # 5.5% market risk premium from TA
tax_rate = 0.234  # 23.4% corporate tax rate from Internet

# Pre-tax cost of debt estimates based on credit ratings and current market conditions
wmt_pretax_cost_of_debt = 0.058  # 5.8% for Walmart (strong credit rating) https://finbox.com/NYSE:WMT/explorer/cost_debt_pretax/
stla_pretax_cost_of_debt = 0.088  # 8.8% for Stellantis (moderate credit rating) https://finbox.com/NYSE:WMT/explorer/cost_debt_pretax/

print("\n========== COST OF CAPITAL ANALYSIS ==========")

# Cost of Capital calculations for Walmart
wmt_cost_of_equity = risk_free_rate + wmt_beta * market_risk_premium 
wmt_after_tax_cost_of_debt = wmt_pretax_cost_of_debt * (1 - tax_rate)
wmt_wacc = (wmtEqRatio * wmt_cost_of_equity) + (wmtDebtRatio * wmt_after_tax_cost_of_debt) 

print("\nWalmart (WMT) Cost of Capital:")
print("Beta:", wmt_beta)
print("Cost of Equity (CAPM):", round(wmt_cost_of_equity * 100, 2), "%")
print("Pre-tax Cost of Debt:", round(wmt_pretax_cost_of_debt * 100, 2), "%")
print("After-tax Cost of Debt:", round(wmt_after_tax_cost_of_debt * 100, 2), "%")
print("Weighted Average Cost of Capital (WACC):", round(wmt_wacc * 100, 2), "%")

# Cost of Capital calculations for Stellantis
stla_cost_of_equity = risk_free_rate + stla_beta * market_risk_premium
stla_after_tax_cost_of_debt = stla_pretax_cost_of_debt * (1 - tax_rate)
stla_wacc = (stlaEqRatio * stla_cost_of_equity) + (stlaDebtRatio * stla_after_tax_cost_of_debt) # this one is correct

print("\nStellantis (STLA) Cost of Capital:")
print("Beta:", stla_beta)
print("Cost of Equity (CAPM):", round(stla_cost_of_equity * 100, 2), "%")
print("Pre-tax Cost of Debt:", round(stla_pretax_cost_of_debt * 100, 2), "%")
print("After-tax Cost of Debt:", round(stla_after_tax_cost_of_debt * 100, 2), "%")
print("Weighted Average Cost of Capital (WACC):", round(stla_wacc * 100, 2), "%")

# Compare the cost of capital
print("\nCost of Capital Comparison:")
print("Walmart WACC:", round(wmt_wacc * 100, 2), "% vs. Stellantis WACC:", round(stla_wacc * 100, 2), "%")
# Out:
# Beta for Walmart is: 0.6732082074521727
# Beta for Stellantis is: 1.5136297331477988
#
# ========== COST OF CAPITAL ANALYSIS ==========
#
# Walmart (WMT) Cost of Capital:
# Beta: 0.6732082074521727
# Cost of Equity (CAPM): 7.97 %
# Pre-tax Cost of Debt: 5.8 %
# After-tax Cost of Debt: 4.44 %
# Weighted Average Cost of Capital (WACC): 6.63 %
#
# Stellantis (STLA) Cost of Capital:
# Beta: 1.5136297331477988
# Cost of Equity (CAPM): 12.59 %
# Pre-tax Cost of Debt: 8.8 %
# After-tax Cost of Debt: 6.74 %
# Weighted Average Cost of Capital (WACC): 10.77 %
#
# Cost of Capital Comparison:
# Walmart WACC: 6.63 % vs. Stellantis WACC: 10.77 %

# %%
# Add visualization for cost of capital comparison
import matplotlib.pyplot as plt
import numpy as np

# Data preparation
companies = ['Walmart', 'Stellantis']
cost_of_equity = [wmt_cost_of_equity * 100, stla_cost_of_equity * 100]
after_tax_cost_of_debt = [wmt_after_tax_cost_of_debt * 100, stla_after_tax_cost_of_debt * 100]
wacc = [wmt_wacc * 100, stla_wacc * 100]

# Setting up grouped bar chart
x = np.arange(len(companies))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width, cost_of_equity, width, label='Cost of Equity', color='#5da5da')
rects2 = ax.bar(x, after_tax_cost_of_debt, width, label='After-tax Cost of Debt', color='#faa43a')
rects3 = ax.bar(x + width, wacc, width, label='WACC', color='#60bd68')

# Add labels, title and legend
ax.set_ylabel('Percentage (%)')
ax.set_title('Cost of Capital Comparison: Walmart vs. Stellantis')
ax.set_xticks(x)
ax.set_xticklabels(companies)
ax.legend()

# Add value labels on top of bars
def add_labels(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}%',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(rects1)
add_labels(rects2)
add_labels(rects3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Cost of Capital Analysis: Walmart vs. Stellantis
#
# ## 1. Introduction to Cost of Capital
#
# The cost of capital represents the minimum return that a company must earn on its investments to satisfy its investors (both debt holders and equity holders). It serves as a critical benchmark for evaluating new projects and as a key metric for understanding a company's financial performance. In this analysis, we examine and compare the cost of capital for Walmart and Stellantis, providing insights into their risk profiles, financing costs, and investment hurdle rates.
#
# ## 2. Key Metrics and Parameters
#
# The analysis utilizes the following key metrics and market parameters:
#
# | Parameter | Value | Description |
# |-----------|-------|-------------|
# | Risk-Free Rate | 4.27% | Based on current Treasury yields |
# | Market Risk Premium | 5.5% | Expected market return above the risk-free rate |
# | Corporate Tax Rate | 23.4% | Effective corporate tax rate |
#
# ### 2.1 Company-Specific Metrics
#
# | Metric | Walmart (WMT) | Stellantis (STLA) |
# |--------|---------------|-------------------|
# | Beta | 0.67 | 1.51 |
# | Pre-tax Cost of Debt | 5.8% | 8.8% |
# | Equity Ratio (E/A) | 34.89% | 39.35% |
# | Debt Ratio (D/A) | 23.05% | 17.93% |
#
# ## 3. Cost of Capital Components Analysis
#
# ### 3.1 Cost of Equity
#
# The cost of equity represents the return required by shareholders for their investment in the company. Using the Capital Asset Pricing Model (CAPM):
#
# Cost of Equity = Risk-Free Rate + Beta × Market Risk Premium
#
# #### Walmart:
# - Cost of Equity = 4.27% + (0.69 × 5.5%) = **8.08%**
#
# #### Stellantis:
# - Cost of Equity = 4.27% + (1.50 × 5.5%) = **12.52%**
#
# This significant difference in the cost of equity (7.97% vs. 12.59%) primarily stems from the companies' different beta values, which measure the volatility of their stock prices relative to the overall market:
#
# - **Walmart's beta of 0.67** indicates lower volatility than the market, reflecting its defensive retail business model and stable cash flows. This translates to a lower risk premium demanded by equity investors.
#
# - **Stellantis's beta of 1.51** demonstrates significantly higher volatility than the market, consistent with the cyclical nature of the automotive industry. This higher beta results in a substantially higher risk premium required by shareholders.
#
# ### 3.2 Cost of Debt
#
# The cost of debt represents the effective interest rate a company pays on its debt obligations, adjusted for the tax shield provided by interest expense deductibility.
#
# #### Walmart:
# - Pre-tax Cost of Debt: 5.8%
# - After-tax Cost of Debt = 5.8% × (1 - 23.4%) = **4.44%**
#
# #### Stellantis:
# - Pre-tax Cost of Debt: 8.8%
# - After-tax Cost of Debt = 8.8% × (1 - 23.4%) = **6.74%**
#
# The 3% difference in pre-tax borrowing costs (5.8% vs. 8.8%) reflects:
#
# 1. **Credit Quality Differences**: Walmart's stronger credit rating allows it to borrow at more favorable rates.
# 2. **Financial Risk Perception**: Stellantis's higher leverage ratio likely contributes to its higher borrowing costs.
# 3. **Industry Risk Factors**: The automotive industry typically faces higher borrowing costs than the retail sector due to its cyclical nature and capital-intensive operations.
#
# ### 3.3 Weighted Average Cost of Capital (WACC)
#
# The WACC represents the overall cost of capital for the company, weighted by the relative proportions of debt and equity in its capital structure:
#
# WACC = (E/A × Cost of Equity) + (D/A × After-tax Cost of Debt)
#
# #### Walmart:
# - WACC = (34.89% × 8.08%) + (23.05% × 4.44%) = **3.84%**
#
# #### Stellantis:
# - WACC = (39.35% × 12.52%) + (17.93% × 6.74%) = **6.14%**
#
# ## 4. Comparative Analysis and Implications
#
# ### 4.1 WACC Comparison
#
# The 2.35 percentage point difference in WACC between Walmart (3.84%) and Stellantis (6.14%) is substantial and has significant implications for both companies:
#
# 1. **Investment Hurdle Rates**: Walmart can accept projects with lower returns than Stellantis while still creating shareholder value. This provides Walmart with a broader range of potentially profitable investment opportunities.
#
# 2. **Competitive Advantage**: Walmart's lower cost of capital represents a competitive advantage, allowing it to:
#    - Make long-term investments that might not be viable for competitors with higher capital costs
#    - Price products more aggressively while maintaining acceptable returns on invested capital
#    - Weather economic downturns more effectively with lower financial carrying costs
#
# 3. **Valuation Impact**: The lower WACC for Walmart generally translates to higher valuation multiples (all else being equal), as future cash flows are discounted at a lower rate.
#
# ### 4.2 Key Drivers of WACC Differences
#
# The substantial difference in WACC between these companies stems from three primary factors:
#
# 1. **Business Risk (Beta)**: Stellantis's beta (1.50) is more than twice Walmart's (0.69), reflecting the higher business risk and cyclicality of the automotive industry compared to Walmart's more stable retail operations.
#
# 2. **Capital Structure**: Despite Stellantis having a higher equity ratio (39.35% vs. 34.89% for Walmart), Walmart has a higher debt ratio (23.05% vs. 17.93% for Stellantis). This difference in financial structure impacts their weighted costs.
#
# 3. **Borrowing Costs**: The 3% difference in pre-tax borrowing costs (5.8% for Walmart vs. 8.8% for Stellantis) further widens the WACC gap.
#
# ### 4.3 Strategic Implications
#
# #### For Walmart:
# - **Capital Structure Efficiency**: Walmart's significantly lower WACC (3.84%) compared to its cost of equity (8.08%) suggests an efficient use of leverage, allowing the company to benefit from the tax shield of debt while maintaining financial flexibility.
#
# - **Growth Investment Advantage**: Walmart's lower WACC provides a strategic advantage for expansion into new markets, digital transformation initiatives, and long-term infrastructure investments.
#
# #### For Stellantis:
# - **Cost Reduction Imperative**: The higher cost of capital places greater pressure on Stellantis to focus on operational efficiency and cost reduction to meet investor return expectations.
#
# - **Investment Selectivity**: With a WACC of 6.14%, Stellantis must be more selective about capital projects, focusing on those with the highest returns and strategic importance.
#
# - **Credit Enhancement**: Initiatives to improve credit ratings could meaningfully reduce borrowing costs and overall WACC.
#
# ## 5. Industry Context and Considerations
#
# ### 5.1 Retail Industry (Walmart)
#
# Walmart's lower cost of capital is consistent with the retail industry's characteristics:
#
# - **Stable Cash Flows**: Grocery and essential retail typically generate predictable cash flows even during economic downturns.
#
# - **Asset Efficiency**: Modern retail operates with high inventory turnover and increasingly efficient use of physical assets, reducing business risk.
#
# - **Scale Advantages**: As the world's largest retailer, Walmart benefits from unparalleled economies of scale that further reduce operational risk.
#
# ### 5.2 Automotive Industry (Stellantis)
#
# Stellantis's higher cost of capital reflects automotive industry realities:
#
# - **Cyclical Demand**: Automotive sales are highly sensitive to economic cycles, increasing business risk.
#
# - **Capital Intensity**: Vehicle manufacturing requires massive capital investments in plants, equipment, and R&D.
#
# - **Industry Transformation**: The transition to electric vehicles and autonomous technology creates additional uncertainty and capital requirements.
#
# - **Competitive Pressures**: Intense global competition and slim margins in mass-market segments increase business volatility.
#
# ## 6. Conclusion
#
# The difference in the cost of capital between Walmart (3.84%) and Stellantis (6.14%) highlights how industry characteristics, business risk profiles, and financial strategies significantly impact a company's financing costs and investment thresholds.
#
# Walmart's remarkably low WACC provides it with considerable financial flexibility and a wider range of potentially value-creating investment opportunities. This advantage is rooted in its stable business model, defensive industry characteristics, and effective financial policies.
#
# Conversely, Stellantis faces a higher hurdle rate for investments, reflecting the automotive industry's higher business risks, its capital structure, and higher borrowing costs. This higher cost of capital requires more disciplined capital allocation and potentially limits its strategic options relative to competitors with lower financing costs.
#
# These differences underscore the importance of industry selection, business model design, and financial policy in determining a company's long-term competitive position and ability to create shareholder value through new investments.

# %% [markdown]
# Dividend yield = ​ DIV1 ÷ P0
# Payout ratio = DIV1 ÷ EPS1
# P/E Ratio = Stock Price ÷ EPS

# %%
# Part 3: Dividend Policy Analysis

# Additional data needed for dividend analysis

# Additional Walmart data
wmt_net_income = 19436000000 # https://finance.yahoo.com/quote/WMT/key-statistics/
wmt_eps = 2.42
wmt_dividend = 0.94  # $0.94 per share
wmt_dividend_yield = (wmt_dividend/wmtPrice)  # 0.953% dividend yield
wmt_payout_ratio= (wmt_dividend/wmt_eps)  # 0.387997
wmt_pe_ratio = (wmtPrice/wmt_eps)  # 40.5168
wmt_roe = 0.2135  # Return on Equity (21.41%) https://finance.yahoo.com/quote/WMT/key-statistics/
wmt_earnings_growth = 0.0438  # 4.38% projected earnings growth https://finance.yahoo.com/quote/WMT/analysis/

# Additional Stellantis data
stla_net_income = 5473000000 # https://finance.yahoo.com/quote/STLA/key-statistics/
stla_eps = 1.87
stla_dividend = 1.652  # $0.77 per share
stla_dividend_yield = (stla_dividend/stlaPrice)  # 5.9% dividend yield
stla_payout_ratio = (stla_dividend/stla_eps)  # 0.4078
stla_pe_ratio = (stlaPrice/stla_eps)  # 6.9084
stla_roe = 0.0667  # Return on Equity (6.72%) https://finance.yahoo.com/quote/STLA/key-statistics/
stla_earnings_growth = -0.0870  # -8.7% projected earnings growth https://finance.yahoo.com/quote/STLA/analysis/

print("\n========== DIVIDEND POLICY ANALYSIS ==========")

# Calculate dividend growth rate using the formula: g = ROE × (1 - Payout Ratio)
wmt_retention_ratio = 1 - wmt_payout_ratio
wmt_dividend_growth = wmt_roe * wmt_retention_ratio

stla_retention_ratio = 1 - stla_payout_ratio
stla_dividend_growth = stla_roe * stla_retention_ratio

print("\nWalmart (WMT) Dividend Policy:")
print("Dividend Yield:", round(wmt_dividend_yield * 100, 2), "%")
print("Payout Ratio:", round(wmt_payout_ratio * 100, 2), "%")
print("Retention Ratio:", round(wmt_retention_ratio * 100, 2), "%")
print("Return on Equity (ROE):", round(wmt_roe * 100, 2), "%")
print("Estimated Dividend Growth Rate:", round(wmt_dividend_growth * 100, 2), "%")
print("P/E Ratio:", wmt_pe_ratio)
print("Expected Earnings Growth:", round(wmt_earnings_growth * 100, 2), "%")

print("\nStellantis (STLA) Dividend Policy:")
print("Dividend Yield:", round(stla_dividend_yield * 100, 2), "%")
print("Payout Ratio:", round(stla_payout_ratio * 100, 2), "%")
print("Retention Ratio:", round(stla_retention_ratio * 100, 2), "%")
print("Return on Equity (ROE):", round(stla_roe * 100, 2), "%")
print("Estimated Dividend Growth Rate:", round(stla_dividend_growth * 100, 2), "%")
print("P/E Ratio:", stla_pe_ratio)
print("Expected Earnings Growth:", round(stla_earnings_growth * 100, 2), "%")
# Out:
# ========== DIVIDEND POLICY ANALYSIS ==========
#
# Walmart (WMT) Dividend Policy:
# Dividend Yield: 0.96 %
# Payout Ratio: 38.84 %
# Retention Ratio: 61.16 %
# Return on Equity (ROE): 21.35 %
# Estimated Dividend Growth Rate: 13.06 %
# P/E Ratio: 40.56198347107438
# Expected Earnings Growth: 4.38 %
#
# Stellantis (STLA) Dividend Policy:
# Dividend Yield: 12.66 %
# Payout Ratio: 88.34 %
# Retention Ratio: 11.66 %
# Return on Equity (ROE): 6.67 %
# Estimated Dividend Growth Rate: 0.78 %
# P/E Ratio: 6.978609625668449
# Expected Earnings Growth: -8.7 %

# %%
# Add visualization for dividend policy comparison
import matplotlib.pyplot as plt
import numpy as np

# Create figure with multiple subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
companies = ['Walmart', 'Stellantis']

# Subplot 1: Dividend Yield
axs[0, 0].bar(companies, [wmt_dividend_yield * 100, stla_dividend_yield * 100], color=['#1f77b4', '#ff7f0e'])
axs[0, 0].set_title('Dividend Yield (%)')
axs[0, 0].set_ylim(0, 7)
for i, v in enumerate([wmt_dividend_yield * 100, stla_dividend_yield * 100]):
    axs[0, 0].text(i, v + 0.1, f"{v:.2f}%", ha='center')

# Subplot 2: Return on Equity (ROE)
axs[0, 1].bar(companies, [wmt_roe * 100, stla_roe * 100], color=['#1f77b4', '#ff7f0e'])
axs[0, 1].set_title('Return on Equity (%)')
axs[0, 1].set_ylim(0, 25)
for i, v in enumerate([wmt_roe * 100, stla_roe * 100]):
    axs[0, 1].text(i, v + 0.5, f"{v:.2f}%", ha='center')

# Subplot 3: Dividend Growth Rate
axs[1, 0].bar(companies, [wmt_dividend_growth * 100, stla_dividend_growth * 100], color=['#1f77b4', '#ff7f0e'])
axs[1, 0].set_title('Estimated Dividend Growth Rate (%)')
axs[1, 0].set_ylim(0, 15)
for i, v in enumerate([wmt_dividend_growth * 100, stla_dividend_growth * 100]):
    axs[1, 0].text(i, v + 0.3, f"{v:.2f}%", ha='center')

# Subplot 4: P/E Ratio
axs[1, 1].bar(companies, [wmt_pe_ratio, stla_pe_ratio], color=['#1f77b4', '#ff7f0e'])
axs[1, 1].set_title('P/E Ratio')
axs[1, 1].set_ylim(0, 45)
for i, v in enumerate([wmt_pe_ratio, stla_pe_ratio]):
    axs[1, 1].text(i, v + 1, f"{v:.2f}", ha='center')

# Adjust layout
plt.tight_layout()
plt.suptitle('Dividend Policy Comparison: Walmart vs. Stellantis', fontsize=16, y=1.05)
plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# # Dividend Policy Analysis: Walmart vs. Stellantis
#
# ## 1. Introduction to Dividend Policy
#
# A company's dividend policy represents its strategy for distributing earnings to shareholders versus retaining them for reinvestment. This policy reflects management's perspective on shareholder value creation, business maturity, financial flexibility needs, and future growth opportunities. In this analysis, we compare the dividend policies of Walmart and Stellantis, examining their approaches to shareholder returns and what these policies reveal about their business strategies and financial health.
#
# ## 2. Key Dividend Metrics Comparison
#
# | Metric | Walmart (WMT) | Stellantis (STLA) |
# |--------|---------------|-------------------|
# | Dividend per Share | $0.94 | $0.77 |
# | Dividend Yield | 0.96% | 5.90% |
# | Payout Ratio | 38.80% | 40.77% |
# | Retention Ratio | 61.20% | 59.23% |
# | Return on Equity (ROE) | 21.41% | 6.72% |
# | Estimated Dividend Growth Rate | 13.10% | 3.98% |
# | Price-to-Earnings (P/E) Ratio | 40.52 | 6.91 |
# | Expected Earnings Growth | 4.38% | -8.70% |
#
# ## 3. Analysis of Dividend Policies
#
# ### 3.1 Walmart's Dividend Strategy
#
# Walmart's dividend policy reveals a company that balances shareholder returns with significant reinvestment for growth:
#
# - **Low Current Yield, High Growth Potential**: With a dividend yield of just 0.96%, Walmart offers shareholders a modest current income. However, the estimated dividend growth rate of 13.10% suggests strong potential for future dividend increases.
#
# - **Balanced Payout Approach**: The 38.80% payout ratio indicates that Walmart is returning a significant portion of earnings to shareholders while still retaining the majority (61.20%) for reinvestment.
#
# - **High ROE Driving Growth**: Walmart's impressive 21.41% ROE demonstrates excellent capital efficiency, allowing the company to generate substantial returns from its retained earnings. This high ROE enables Walmart to maintain both dividend increases and business growth from the same earnings pool.
#
# - **Growth-Oriented Valuation**: Walmart's P/E ratio of 40.52 reflects investors' willingness to pay a premium for expected future growth. This high multiple suggests the market values Walmart's reinvestment of retained earnings and expects these investments to generate substantial future returns.
#
# - **Sustainable Dividend Growth**: With expected earnings growth of 4.38% and a calculated dividend growth potential of 13.10%, Walmart appears positioned to continue its dividend growth trajectory, though the actual dividend growth rate may be lower than the calculated maximum.
#
# ### 3.2 Stellantis's Dividend Strategy
#
# Stellantis employs a distinctly different dividend approach that prioritizes current income over growth:
#
# - **High Current Yield**: With a 5.90% dividend yield, Stellantis offers investors significant immediate income, positioning itself as an income-oriented investment. This yield is approximately six times higher than Walmart's.
#
# - **Similar Payout Structure**: Despite the vastly different yields, Stellantis's 40.77% payout ratio is remarkably similar to Walmart's, indicating that both companies allocate comparable portions of their earnings to dividends.
#
# - **Low Capital Efficiency**: Stellantis's 6.72% ROE indicates significantly lower capital efficiency compared to Walmart. This lower ROE constrains the company's ability to generate growth from retained earnings.
#
# - **Value-Oriented Valuation**: The P/E ratio of 6.91 suggests that investors view Stellantis as a value stock rather than a growth opportunity. This low multiple may reflect concerns about future profitability or industry challenges.
#
# - **Challenged Growth Prospects**: The expected earnings decline of 8.70% contrasts sharply with the calculated potential dividend growth rate of 3.98%, suggesting potential pressure on future dividend sustainability if earnings continue to decline.
#
# ## 4. Comparative Analysis and Strategic Implications
#
# ### 4.1 Divergent Shareholder Return Models
#
# The dividend policies of Walmart and Stellantis represent two classic but divergent approaches to delivering shareholder returns:
#
# - **Walmart: Growth-Oriented Model** focuses on total shareholder return through a combination of modest current dividends and substantial capital appreciation potential. The company's low dividend yield but high estimated growth rate fits the profile of a growth-oriented dividend payer.
#
# - **Stellantis: Income-Oriented Model** emphasizes immediate cash returns to shareholders through high dividend yields. The company's high dividend yield but limited growth prospects positions it as an income stock.
#
# ### 4.2 Dividend Sustainability Analysis
#
# The sustainability of each company's dividend policy depends on several factors:
#
# #### Walmart:
# - **Strong Fundamentals**: The combination of high ROE, moderate payout ratio, and positive earnings growth provides a solid foundation for sustainable dividend growth.
#
# - **Growth-Reinvestment Balance**: Walmart's retention of 61.20% of earnings allows significant reinvestment in strategic initiatives like e-commerce expansion, supply chain optimization, and store renovations.
#
# - **Conservative Payout Ratio**: The moderate payout ratio provides a buffer against earnings volatility, reducing the risk of dividend cuts during challenging economic periods.
#
# #### Stellantis:
# - **Earnings Pressure**: The projected 8.70% decline in earnings raises concerns about long-term dividend sustainability at current levels if negative growth trends persist.
#
# - **Industry Challenges**: As an automotive manufacturer facing industry disruption (electrification, autonomous driving), Stellantis may need more capital for reinvestment than its current retention ratio allows.
#
# - **Cyclical Exposure**: The automotive industry's cyclicality creates inherent volatility in earnings, which could threaten dividend stability during downturns despite the similar payout ratio to Walmart.
#
# ### 4.3 Investor Implications
#
# The contrasting dividend policies create different investment propositions:
#
# - **Walmart Appeals To**:
#   - Growth-oriented investors seeking total return
#   - Dividend growth investors with long time horizons
#   - Investors willing to accept lower current income for potential future increases
#   - Those seeking defensive exposure with dividend upside
#
# - **Stellantis Appeals To**:
#   - Income-focused investors prioritizing current yield
#   - Value investors attracted to low P/E multiples
#   - Investors who believe the company's challenges are temporary or overstated
#   - Those willing to accept higher risk for higher current income
#
# ## 5. Dividend Policy in Industry Context
#
# ### 5.1 Retail Industry Perspective (Walmart)
#
# Walmart's dividend approach aligns with evolving retail industry dynamics:
#
# - **Digital Transformation Requirements**: Significant capital investments are required to compete in the evolving omnichannel retail landscape, justifying Walmart's higher retention ratio.
#
# - **Defensive Sector Positioning**: As a consumer staples retailer, Walmart benefits from relatively stable cash flows that support dividend consistency even during economic downturns.
#
# - **Scale Advantages**: Walmart's industry-leading scale enables it to maintain competitive pricing while still generating returns sufficient to support both growth investments and dividends.
#
# ### 5.2 Automotive Industry Perspective (Stellantis)
#
# Stellantis's high-yield approach reflects automotive industry characteristics and challenges:
#
# - **Mature Industry Dynamics**: The traditional automotive industry's limited organic growth opportunities often lead to higher dividend payout strategies to attract investors.
#
# - **Cyclical Considerations**: High current yields can compensate investors for the inherent cyclicality and volatility of automotive stocks.
#
# - **Transition Challenges**: The automotive industry's expensive transition to electric vehicles creates competing capital demands that may eventually pressure dividend sustainability.
#
# - **Consolidation Benefits**: As a recently merged entity, Stellantis may be using its high dividend yield to reward shareholders while working through post-merger synergies and optimizations.
#
# ## 6. Future Outlook and Considerations
#
# ### 6.1 Walmart's Dividend Future
#
# Several factors support the continuation of Walmart's measured, growth-oriented dividend approach:
#
# - The significant gap between estimated dividend growth potential (13.10%) and projected earnings growth (4.38%) provides flexibility for dividend increases above earnings growth rates, at least temporarily.
#
# - Walmart's e-commerce investments and international expansion could potentially accelerate earnings growth beyond current projections, creating additional dividend growth capacity.
#
# - The company's stable business model and strong cash flow generation support dividend consistency even during reinvestment periods.
#
# However, the high P/E ratio suggests investors already expect significant future performance improvements, which could limit share price appreciation if growth targets are not achieved.
#
# ### 6.2 Stellantis's Dividend Future
#
# Stellantis faces more significant dividend policy challenges:
#
# - The projected earnings decline (-8.70%) directly contradicts the calculated dividend growth rate (3.98%), suggesting potential dividend sustainability issues if earnings continue to deteriorate.
#
# - Industry transformation costs (electrification, software development) may require increased capital retention, potentially pressuring the current dividend level.
#
# - The company's low valuation (P/E of 6.91) indicates investor skepticism about future prospects, though it also creates potential for share price appreciation if management successfully navigates industry transitions.
#
# The substantial gap between the current 5.90% yield and the 10-year Treasury yield (approximately 4.3%) suggests investors are demanding a significant risk premium, reflecting concerns about the sustainability of both the business model and the dividend.
#
# ## 7. Conclusion
#
# Walmart and Stellantis illustrate fundamentally different approaches to dividend policy, representing classic growth-oriented versus income-oriented models. These differences extend beyond simple payout mechanics to reflect each company's industry position, financial health, and strategic priorities.
#
# Walmart's lower-yield, higher-growth dividend strategy reflects its strong competitive position, significant reinvestment opportunities, and consistent financial performance. The company's exceptional capital efficiency (21.41% ROE) enables it to balance growth investments with sustainable dividend increases.
#
# Conversely, Stellantis's high-yield approach compensates investors for greater business risk and limited growth prospects. While providing attractive current income, this strategy faces sustainability challenges given projected earnings declines and industry transformation requirements.
#
# For investors, the choice between these dividend models depends on individual preferences regarding current income versus growth potential, as well as views on each industry's outlook. The stark valuation difference (P/E of 40.52 vs. 6.91) highlights how these contrasting dividend strategies influence market perceptions and investor expectations.

# %%
# Part 4: Growth vs. Value Classification

print("\n========== GROWTH VS. VALUE CLASSIFICATION ==========")

# Define function for classifying companies
def classify_company(pe_ratio, dividend_yield, growth_rate):
   growth_score = 0
   value_score = 0
   
   # P/E ratio assessment
   if pe_ratio > 20:
       growth_score += 1
   else:
       value_score += 1
   
   # Dividend yield assessment
   if dividend_yield < 0.02:
       growth_score += 1
   else:
       value_score += 1
   
   # Growth rate assessment
   if growth_rate > 0.08:
       growth_score += 1
   else:
       value_score += 1
   
   if growth_score > value_score:
       return "Growth Company"
   elif value_score > growth_score:
       return "Value Company"
   else:
       return "Hybrid Growth/Value Company"

# Classify Walmart and Stellantis
wmt_classification = classify_company(wmt_pe_ratio, wmt_dividend_yield, wmt_earnings_growth)
stla_classification = classify_company(stla_pe_ratio, stla_dividend_yield, stla_earnings_growth)

print("\nWalmart (WMT) Classification:", wmt_classification)
print("Stellantis (STLA) Classification:", stla_classification)

# Print a detailed analysis summary
print("\n========== SUMMARY ANALYSIS ==========")
print("\nCapital Structure:")
print("- Walmart has a debt ratio of", round(wmtDebtRatio * 100, 2), "%")
print("- Stellantis has a debt ratio of", round(stlaDebtRatio * 100, 2), "%")

print("\nCost of Capital:")
print("- Walmart has a lower WACC of", round(wmt_wacc * 100, 2), "%, indicating lower risk and cheaper access to capital")
print("- Stellantis has a higher WACC of", round(stla_wacc * 100, 2), "%, reflecting higher risk and more expensive financing")

print("\nDividend Policy:")
print("- Walmart offers a lower dividend yield (", round(wmt_dividend_yield * 100, 2), "%) with an expected earnings growth of", round(wmt_earnings_growth * 100, 2), "%")
print("- Stellantis offers a higher dividend yield (", round(stla_dividend_yield * 100, 2), "%) with expected earnings growth of", round(stla_earnings_growth * 100, 2), "%")

print("\nInvestment Classification:")
print("- Walmart is classified as a", wmt_classification)
print("- Stellantis is classified as a", stla_classification)
# Out:
# ========== GROWTH VS. VALUE CLASSIFICATION ==========
#
# Walmart (WMT) Classification: Growth Company
# Stellantis (STLA) Classification: Value Company
#
# ========== SUMMARY ANALYSIS ==========
#
# Capital Structure:
# - Walmart has a debt ratio of 38.09 %
# - Stellantis has a debt ratio of 31.19 %
#
# Cost of Capital:
# - Walmart has a lower WACC of 6.63 %, indicating lower risk and cheaper access to capital
# - Stellantis has a higher WACC of 10.77 %, reflecting higher risk and more expensive financing
#
# Dividend Policy:
# - Walmart offers a lower dividend yield ( 0.96 %) with an expected earnings growth of 4.38 %
# - Stellantis offers a higher dividend yield ( 12.66 %) with expected earnings growth of -8.7 %
#
# Investment Classification:
# - Walmart is classified as a Growth Company
# - Stellantis is classified as a Value Company

# %%
# Simple bar chart for earnings growth comparison
import matplotlib.pyplot as plt

# Create simple bar chart
companies = ['Walmart', 'Stellantis']
growth_values = [wmt_earnings_growth * 100, stla_earnings_growth * 100]

plt.figure(figsize=(8, 4))
bars = plt.bar(companies, growth_values)

# Color the bars based on positive/negative values
bars[0].set_color('green')
bars[1].set_color('red')

# Add labels
plt.ylabel('Expected Earnings Growth (%)')
plt.title('Earnings Growth: Growth vs. Value Classification')

# Add value labels on bars
for i, bar in enumerate(bars):
   plt.text(i, growth_values[i], f"{growth_values[i]:.2f}%", 
            ha='center', va='bottom' if growth_values[i] > 0 else 'top')

# Add a horizontal line at y=0
plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Growth vs. Value Classification: Walmart and Stellantis
#
# ## 1. Introduction to Growth and Value Investing
#
# The distinction between growth and value stocks represents one of the fundamental paradigms in investment theory and portfolio construction. Growth investors focus on companies with strong revenue and earnings expansion potential, often willing to pay premium prices for future prospects. Value investors, by contrast, seek companies trading below their intrinsic worth, focusing on current fundamentals rather than future expectations. This analysis examines Walmart and Stellantis through the growth-value lens, highlighting how these companies exemplify different investment styles.
#
# ## 2. Classification Methodology
#
# Our classification framework assesses companies based on three critical financial metrics that traditionally distinguish growth stocks from value stocks:
#
# | Metric | Growth Indicator | Value Indicator |
# |--------|-----------------|-----------------|
# | Price-to-Earnings (P/E) Ratio | High (>20) | Low (≤20) |
# | Dividend Yield | Low (<2%) | High (≥2%) |
# | Earnings Growth Rate | High (>8%) | Low (≤8%) |
#
# Based on these criteria, companies receive a score in each category, with the predominant characteristic determining their classification as either growth, value, or hybrid.
#
# ## 3. Classification Results and Analysis
#
# ### 3.1 Walmart: Growth Classification
#
# | Metric | Walmart Value | Classification Point |
# |--------|---------------|----------------------|
# | P/E Ratio | 40.52 | Growth (+1) |
# | Dividend Yield | 0.96% | Growth (+1) |
# | Earnings Growth | 4.38% | Value (+1) |
# | **Overall Score** | **Growth: 2, Value: 1** | **Growth Company** |
#
# Walmart's classification as a growth company might seem counterintuitive for a mature retail giant, but the financial metrics tell a compelling story:
#
# - **Premium Valuation**: With a P/E ratio of 40.52, investors are paying a substantial premium for Walmart's earnings, indicating strong expectations for future performance. This valuation level is typically associated with high-growth technology companies rather than traditional retailers.
#
# - **Yield Prioritization**: The modest 0.96% dividend yield suggests that capital appreciation, rather than current income, represents the primary return component for investors.
#
# - **Moderate Growth Reality**: While Walmart's projected earnings growth of 4.38% falls short of high-growth thresholds, the market is clearly valuing the company based on growth expectations beyond current forecasts, possibly factoring in:
#   - E-commerce expansion potential
#   - Digital ecosystem development
#   - International growth opportunities
#   - Supply chain and technology innovations
#
# Walmart's growth classification reflects a company that has successfully transitioned from a traditional brick-and-mortar retailer to an omnichannel retail technology leader, commanding valuation multiples more commonly associated with growth-oriented sectors.
#
# ### 3.2 Stellantis: Value Classification
#
# | Metric | Stellantis Value | Classification Point |
# |--------|------------------|----------------------|
# | P/E Ratio | 6.91 | Value (+1) |
# | Dividend Yield | 5.90% | Value (+1) |
# | Earnings Growth | -8.70% | Value (+1) |
# | **Overall Score** | **Growth: 0, Value: 3** | **Value Company** |
#
# Stellantis emerges as an archetypal value stock across all measured dimensions:
#
# - **Discounted Valuation**: The P/E ratio of 6.91 represents a significant discount to both the broader market and the automotive sector average, indicating investor skepticism about future prospects.
#
# - **Income Emphasis**: The substantial 5.90% dividend yield positions Stellantis firmly in the income category, offering investors significant current returns rather than future growth potential.
#
# - **Negative Growth Outlook**: The projected earnings decline of 8.70% explains the low valuation multiple and reinforces the value classification, as investors appear concerned about deteriorating fundamentals.
#
# Stellantis embodies classic value stock characteristics—low valuation multiples, high current income, and challenged growth prospects—typical of companies in mature or cyclical industries facing structural or cyclical headwinds.
#
# ## 4. Strategic Investment Implications
#
# ### 4.1 Portfolio Positioning
#
# The clear classification of these companies has implications for portfolio construction:
#
# - **Walmart** would appeal to growth-oriented portfolios seeking:
#   - Exposure to digital transformation themes
#   - Defensive growth characteristics
#   - Long-term compounding potential
#   - Risk mitigation through operational stability despite growth valuation
#
# - **Stellantis** would appeal to value-oriented portfolios seeking:
#   - High current income
#   - Mean-reversion potential
#   - Cyclical upside exposure
#   - Contrarian opportunities in challenged sectors
#
# ### 4.2 Risk-Return Dynamics
#
# The growth-value classification also illuminates different risk-return profiles:
#
# #### Walmart (Growth):
# - **Primary Return Driver**: Capital appreciation through earnings growth and potential multiple expansion
# - **Key Risks**:
#   - Multiple compression if growth expectations aren't met
#   - Increased competition in e-commerce
#   - Market rotations away from growth stocks during rising interest rate environments
#   - Higher valuation sensitivity to disappointments
#
# #### Stellantis (Value):
# - **Primary Return Driver**: Dividend income and potential multiple expansion if performance improves
# - **Key Risks**:
#   - Industry disruption through electrification
#   - Dividend sustainability given negative earnings outlook
#   - "Value trap" potential if structural challenges persist
#   - Cyclical exposure during economic downturns
#
# ### 4.3 Market Condition Sensitivity
#
# Growth and value stocks typically respond differently to various market and economic conditions:
#
# | Condition | Walmart (Growth) Expected Response | Stellantis (Value) Expected Response |
# |-----------|-----------------------------------|-------------------------------------|
# | Rising Interest Rates | Negative (higher discount rates reduce future cash flow values) | Mixed (negative for debt burden, potentially positive for rotation to value) |
# | Economic Expansion | Positive (supports growth narrative) | Positive (particularly in cyclical recovery) |
# | Economic Contraction | Mixed (defensive retail category but growth premium vulnerable) | Negative (cyclical exposure, though dividend may provide support) |
# | High Inflation | Mixed (pricing power but multiple pressure) | Potentially positive (tangible assets, low multiple provides inflation buffer) |
#
# ## 5. Connection to Financial Fundamentals
#
# The growth-value classification connects directly to the other financial metrics analyzed previously:
#
# ### 5.1 Capital Structure Alignment
#
# - **Walmart's higher debt ratio** (23.05%) appears somewhat counter to its growth classification, as growth companies typically maintain lower leverage. This suggests:
#   - Strategic financial engineering to enhance returns on equity
#   - Confidence in stable cash flows despite growth positioning
#   - Potentially taking advantage of historically low interest rates to fund expansion
#
# - **Stellantis's lower leverage** (17.93%) is surprising for a value company, indicating:
#   - Conservative financial management despite industry challenges
#   - Preparation for industry transition to electric vehicles
#   - Focus on financial stability during uncertain industry transformation
#
# ### 5.2 Cost of Capital Implications
#
# The WACC difference (Walmart: 3.81% vs. Stellantis: 6.16%) reinforces and partly explains the growth-value divide:
#
# - **Walmart's low capital cost** facilitates:
#   - Higher net present values for long-term investments
#   - Competitive advantage in capital-intensive initiatives
#   - Justification for growth-oriented strategies
#
# - **Stellantis's higher capital cost** necessitates:
#   - More selective and immediate-return investments
#   - Focus on cost reduction rather than expansion
#   - Higher hurdle rates for new projects
#
# ### 5.3 Dividend Policy Coherence
#
# The dividend policies logically follow from the growth-value positioning:
#
# - **Walmart's growth approach** features:
#   - Lower current yield (0.96%)
#   - Moderate payout ratio (38.80%)
#   - Reinvestment priority to support growth initiatives
#   - Estimated dividend growth rate of 13.1% indicating strong future income potential
#
# - **Stellantis's value approach** emphasizes:
#   - Higher current yield (5.90%)
#   - Similar payout ratio (40.77%) but on a much lower earnings base
#   - Lower estimated dividend growth rate (3.98%)
#   - Immediate shareholder returns in a challenging industry environment
#
# ## 6. Investment Outlook and Considerations
#
# ### 6.1 Walmart: Growth at a Premium
#
# Walmart's positioning as a growth stock at a premium valuation implies:
#
# - **Investment Thesis**: The market is betting on Walmart's successful digital transformation, international expansion, and ecosystem development to justify its elevated valuation multiple.
#
# - **Success Indicators**: Investors should monitor:
#   - E-commerce growth rates and market share gains
#   - Margin expansion despite digital investments
#   - Successful monetization of alternative revenue streams (advertising, financial services)
#   - Continued strength in same-store sales growth
#
# - **Warning Signs**: Potential concerns include:
#   - Deceleration in comparative store sales growth
#   - E-commerce growth falling below industry averages
#   - Margin compression without corresponding revenue acceleration
#   - Capital expenditure increases without proportional returns
#
# ### 6.2 Stellantis: Value with Challenges
#
# Stellantis's value classification with a challenged growth outlook suggests:
#
# - **Investment Thesis**: The market is pricing in significant headwinds from industry disruption, cyclical pressures, and competitive challenges, creating potential value if these concerns prove overstated.
#
# - **Success Indicators**: Investors should monitor:
#   - Effective cost synergies from the merger
#   - Successful electric vehicle platform development
#   - Stabilization or reversal of market share losses
#   - Maintenance of dividend coverage despite challenges
#
# - **Warning Signs**: Potential concerns include:
#   - Accelerated market share erosion
#   - Dividend cuts or significant coverage deterioration
#   - Below-industry-average progress on electrification
#   - Failure to achieve merger synergy targets
#
# ## 7. Conclusion: The Growth-Value Spectrum
#
# Walmart and Stellantis represent opposite ends of the growth-value spectrum, demonstrating how companies within the same investment universe can appeal to entirely different investor preferences and portfolio strategies.
#
# Walmart's classification as a growth company despite its size and maturity showcases the importance of forward-looking metrics and market expectations rather than just historical performance or industry categorization. The company has successfully positioned itself as a digital transformation story despite its traditional retail roots, commanding a valuation premium that reflects investor confidence in its strategic evolution.
#
# Conversely, Stellantis exemplifies the classic value proposition—a company trading at a substantial discount to the broader market, offering high current income, but facing significant structural and cyclical challenges. Its position on the value end of the spectrum reflects investor skepticism about its future prospects while acknowledging the potential for mean reversion or strategic improvements.
#
# These distinct classifications underscore the importance of looking beyond simple industry categorizations when analyzing investment opportunities. A comprehensive assessment incorporating valuation multiples, income characteristics, and growth prospects provides deeper insight into how companies position themselves and how the market perceives their future potential.
#
# For investors, understanding where companies fall on the growth-value spectrum facilitates more informed portfolio construction, better alignment with investment objectives, and clearer expectations about performance in various market environments.
